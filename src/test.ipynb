# %%
import requests

data = {
    "columns":[
        "PassengerId", "Survived", "Pclass", "Name", "Sex", "Age",
        "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"

    ],
    "rows":[
        [1, 0, 3, "Braund, Mr. Owen Harris", "male", 22, 1, 0, "A/5 21171", 7.25, None, "S"]
    ]
}

response = requests.get(url="http://0.0.0.0:8000",json=data)
